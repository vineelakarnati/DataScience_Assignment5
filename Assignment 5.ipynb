# %%
import pandas as pd

# %%
#read data from url which is in csv format
df = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv")

# %%
df
# Out:
#          Unnamed: 0       Id       Name  Year Gender State  Count
# 0             11349    11350       Emma  2004      F    AK     62
# 1             11350    11351    Madison  2004      F    AK     48
# 2             11351    11352     Hannah  2004      F    AK     46
# 3             11352    11353      Grace  2004      F    AK     44
# 4             11353    11354      Emily  2004      F    AK     41
# 5             11354    11355    Abigail  2004      F    AK     37
# 6             11355    11356     Olivia  2004      F    AK     33
# 7             11356    11357   Isabella  2004      F    AK     30
# 8             11357    11358     Alyssa  2004      F    AK     29
# 9             11358    11359     Sophia  2004      F    AK     28
# 10            11359    11360     Alexis  2004      F    AK     27
# 11            11360    11361  Elizabeth  2004      F    AK     27
# 12            11361    11362     Hailey  2004      F    AK     27
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'Name', 'Year', 'Gender', 'State', 'Count'], dtype='object')

# %%
#1.Delete Unnamed Columns
df = df.loc[ : ,~df.columns.str.contains('^Unnamed')]
df
# Out:
#               Id       Name  Year Gender State  Count
# 0          11350       Emma  2004      F    AK     62
# 1          11351    Madison  2004      F    AK     48
# 2          11352     Hannah  2004      F    AK     46
# 3          11353      Grace  2004      F    AK     44
# 4          11354      Emily  2004      F    AK     41
# 5          11355    Abigail  2004      F    AK     37
# 6          11356     Olivia  2004      F    AK     33
# 7          11357   Isabella  2004      F    AK     30
# 8          11358     Alyssa  2004      F    AK     29
# 9          11359     Sophia  2004      F    AK     28
# 10         11360     Alexis  2004      F    AK     27
# 11         11361  Elizabeth  2004      F    AK     27
# 12         11362     Hailey  2004      F    AK     27
# 13         11363       Anna  2004      F    AK     26
# 14         11364    Natalie  2004      F    AK     25
# 15         11365      Sarah  2004      F    AK     25
# ...

# %%
#2.Show the distribution of Male and Female
import matplotlib.pyplot as plt
gbg = df.groupby(["Gender"]).count()
gbg.loc[:,'Count']
# Out:
# Gender
# F    558846
# M    457549
# Name: Count, dtype: int64

# %%
#3.Top 5 most preffered names
df['Name'].value_counts().sort_values(ascending=False).head(5)
# Out:
# Riley     1112
# Avery     1080
# Jordan    1073
# Peyton    1064
# Hayden    1049
# Name: Name, dtype: int64

# %%
#4.Median name occured in the dataset
unique_index = pd.Index(df.Id)
df.loc[unique_index.get_loc(df.median().Id),'Name']
# Out:
# 'Kasey'

# %%
#5.Distribution of Male and Female Born count by States
state_count = df.groupby(["Gender","State"]).count()
state_count.loc[:,'Count']
# Out:
# Gender  State
# F       AK        2404
#         AL        9878
#         AR        7171
#         AZ       14518
#         CA       45144
#         CO       11424
#         CT        6575
#         DC        3053
#         DE        2549
#         FL       25781
#         GA       19385
#         HI        3255
#         IA        7131
#         ID        4918
#         IL       21268
#         IN       13056
#         KS        7753
#         KY        8817
#         LA       10510
#         MA       10580
#         MD       11276
#         ME        2976
#         MI       16038
#         MN       10677
#         MO       11948
#         MS        7235
#         MT        2690
#         NC       17357
#         ND        2399
#         NE        5370
#                  ...
# M       ME        2777
#         MI       13243
#         MN        9004
#         MO        9917
#         MS        6862
#         MT        2986
#         NC       13530
#         ND        2581
# ...

# %% [markdown]
# # Task 2

# %%
# Question : We have the min and max temperatures in a city In India for each months of the year. We
# would like to find a function to describe this and show it graphically, the dataset given below.
# Task:
# 1. fitting it to the periodic function
# 2. plot the fit
import matplotlib.pyplot as plt
import numpy as np

temp_max = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
temp_min = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])

weeks = np.linspace(0, 12, num=52)
months = np.arange(12)

# %%
from scipy import optimize
def yearly_temps(times, avg, ampl, time_offset):
   return (avg
           + ampl * np.cos((times + time_offset) * 2 * np.pi / times.max()))

res_max, cov_max = optimize.curve_fit(yearly_temps, months,
                                     temp_max)
res_min, cov_min = optimize.curve_fit(yearly_temps, months,
                                     temp_min)

# %%
plt.plot(months, temp_max, 'ro')
plt.plot(weeks, yearly_temps(weeks, *res_max), 'r-')
plt.plot(months, temp_min, 'bo')
plt.plot(weeks, yearly_temps(weeks, *res_min), 'b-')
plt.xlabel('Month')
plt.ylabel('Min and max temperature')
# Out:
# Text(0,0.5,'Min and max temperature')
